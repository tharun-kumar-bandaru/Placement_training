# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the data

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.describe() # one
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include = "object") # two
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
## Missing values

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
missing_percent = (df.isnull().sum() / (len(df)))

# %%
missing_percent
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %% [markdown]
# ## when the data will be < 5 replace with manipulation and
#                       > 50 remove the columns

# %%
df["age"].hist()
# Out:
# <Axes: >

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
df["embarked"] = df["embarked"].fillna(df["embarked"].mode())

# %%
df["embarked"].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
df["embarked"].mode()[0]
# Out:
# 'S'

# %%
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

# %%
df["embark_town"] = df["embark_town"].fillna(df["embark_town"].mode()[0])

# %%
df.isnull().sum() ## here deck 688 values
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.drop(columns = ["deck"], inplace = True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
## Duplicate data

# %%
df.duplicated().sum()
# Out:
# np.int64(116)

# %%
np.int64(116)
# Out:
# np.int64(116)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Data Type cleaning

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
## Boolean to int
df["adult_male"] = df["adult_male"].astype(int)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10556\2036977601.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["adult_male"] = df["adult_male"].astype(int)

# %%
df["alone"] = df["alone"].astype(int)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10556\1074949820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["alone"] = df["alone"].astype(int)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man           1  Southampton    no      0
# 1  woman           0    Cherbourg   yes      0
# 2  woman           0  Southampton   yes      1
# 3  woman           0  Southampton   yes      0
# 4    man           1  Southampton    no      1

# %%
df["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["sex"] = df["sex"].str.lower()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10556\985854172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sex"] = df["sex"].str.lower()

# %%
df["embark_town"] = df["embark_town"].str.strip() ## to remove space
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10556\4241902304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["embark_town"] = df["embark_town"].str.strip()

# %% [markdown]
# ### Out liers

# %%
sns.boxplot(df["fare"])
# Out:
# <Axes: ylabel='fare'>

# %%
## Formula to remove outliers
Q1 = df["fare"].quantile(0.25) 
Q3 = df["fare"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
## identify the outliers

# %%
outliers = df[(df["fare"] < lower) | (df["fare"] > upper)] ## to see outliers

# %%
outliers
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 54          0       1    male  65.0      0      1  61.9792        C   First
# 74          1       3    male  32.0      0      0  56.4958        S   Third
# 92          0       1    male  46.0      1      0  61.1750        S   First
# 97          1       1    male  23.0      0      1  63.3583        C   First
# 151         1       1  female  22.0      1      0  66.6000        S   First
# 155         0       1    male  51.0      0      1  61.3792        C   First
# 159         0       3    male  28.0      8      2  69.5500        S   Third
# 166         1       1  female  28.0      0      1  55.0000        S   First
# 169         0       3    male  28.0      0      0  56.4958        S   Third
# 180         0       3  female  28.0      8      2  69.5500        S   Third
# ...

# %%
## remove outliers

# %%
df = df[(df["fare"] >= lower) & (df["fare"] <= upper)]

# %%
sns.boxplot(df["fare"])
# Out:
# <Axes: ylabel='fare'>

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male  28.0      0      0   8.4583        Q  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man           1  Southampton    no      0
# 2  woman           0  Southampton   yes      1
# 3  woman           0  Southampton   yes      0
# 4    man           1  Southampton    no      1
# 5    man           1   Queenstown    no      1

# %%
df["survived"].value_counts()
# Out:
# survived
# 0    418
# 1    225
# Name: count, dtype: int64

# %%
df["pclass"].value_counts()
# Out:
# pclass
# 3    395
# 2    157
# 1     91
# Name: count, dtype: int64

# %%
## save date to new file

# %%
df.to_csv("titanic_data_cleaned.csv", index = False)

# %%
### resulable data quality report function

# %%
def dara_quality_report(df):
    report = {
        "shape": df.shape,
        "missing_values": df.isnull().sum(),
        "duplicate_count": int(df.duplicated().sum()),
        "data_type": df.dtypes.astype(str).to_dict()

    }
