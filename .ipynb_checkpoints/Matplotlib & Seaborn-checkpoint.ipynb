# %% [markdown]
# ### Matplotlib
#
# figure canva
#
# axes: individual plots inside thr figure

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace(0,10,100)

# %%
y = np.sin(x)

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label = "sin(x)", color = "green")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("sine_wave")
ax.legend()
plt.show()

# %%
epochs = np.arange(1,21)

# %%
train_loss = np.exp(-epochs/5) + np.random.rand(20)*0.5

# %%
val_loss = np.exp(-epochs/6) + np.random.rand(20)*0.08

# %%
plt.plot(epochs, train_loss, label = "train")
plt.plot(epochs, val_loss, label = "validity")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.title("Training VS Validation loss")
plt.legend()
plt.show()

# %%
## scatter plot

# %%
x = np.random.rand(200)

# %%
y = 2*x + np.random.rand(200)*0.5

# %%
plt.scatter(x, y)

# %%
## Bar plot

# %%
models = ["LogReg", "RF", "SVM", "XGB"]
acc = [0.82, 0.88, 0.85, 0.91]

# %%
plt.bar(models, acc, color = "red")
plt.ylabel("accuracy")
plt.xlabel("models")
plt.title("Model Comparision")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Histogram

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins = 30, color = "Blue", edgecolor = "black")
plt.title("Histogram")
plt.xlabel("value")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
## subplots

# %%
fig, axes = plt.subplots(1, 2, figsize = (10,4))
axes[0].plot(epochs, train_loss)
axes[1].hist(data, bins = 30)
# Out:
# (array([  1.,   0.,   0.,   0.,   1.,   3.,   6.,   7.,  12.,  15.,  28.,
#          28.,  42.,  67.,  88.,  78.,  89., 114.,  96.,  73.,  68.,  62.,
#          41.,  34.,  23.,   9.,   9.,   2.,   1.,   3.]),
#  array([-4.15872074, -3.91273095, -3.66674117, -3.42075138, -3.1747616 ,
#         -2.92877181, -2.68278203, -2.43679225, -2.19080246, -1.94481268,
#         -1.69882289, -1.45283311, -1.20684332, -0.96085354, -0.71486376,
#         -0.46887397, -0.22288419,  0.0231056 ,  0.26909538,  0.51508517,
#          0.76107495,  1.00706473,  1.25305452,  1.4990443 ,  1.74503409,
#          1.99102387,  2.23701366,  2.48300344,  2.72899322,  2.97498301,
#          3.22097279]),
#  <BarContainer object of 30 artists>)

# %%
## seaborn

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
sns.histplot(data = iris, x = "sepal_length", hue = "species", kde = True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.boxplot(data = iris, x = "species", y = "petal_length")
plt.title("Box-Plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.violinplot(data = iris, x = "species", y = "petal_length")
plt.title("violin plot - Distribution space")
plt.show()

# %%
corr = iris.drop(columns = ["species"]).corr()
